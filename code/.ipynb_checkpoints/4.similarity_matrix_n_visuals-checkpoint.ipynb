# %% [markdown]
# # Building a similarity matrix

# %% [markdown]
# I am now going to make a similarity matrix so that I can see how similar the different hoods are based on quantitative measures.  I measured multiple types of crime in past year, quality of life issues in past year, types of business open/opening in the past year, fog, types of houses for sale (e.g., # of bedrooms), tranportation connectivity to the rest of the city.

# %%
import pandas as pd
import numpy as np
import csv
from sklearn.metrics import pairwise
from sklearn.decomposition import PCA
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#open the data
sf_hoods=pd.read_csv(open('/Users/anson/Documents/Office/zipfian/repos/Personal_project/hoods_data/final_to_analyze/SF_hoods_density_full_1-27-14.csv'))
del sf_hoods['Unnamed: 0']

feature_names = filter(lambda x: x not in ['hood'], sf_hoods.columns)

#data without the hood name; all float data that can be run through algorithms
X = sf_hoods[feature_names]
#the names of the hoods
hood_names = sf_hoods['hood']

# %% [markdown]
# ## Run PCA on data set to reduce dataset

# %% [markdown]
# Many of my features are highly correlated.  For example, I have multiple types of 311 (quality of life) calls and I'm sure many of them reflect a similar latent factor.  If I didn't reduce these data, I would bias the similarity matrix to this latent factor, simply because there are more 'quality of life' features (e.g., more columns describing types of crime) than features reflecting other types of important latent factors.
#
# I am going to plot variance explained by each component to decide how many to keep.  I want to keep basically all of the variance explained by my variables (99%); I just want to reduce redundant variables.

# %%
#total number of columns/features in data set
X.shape
# Out:
# (111, 69)

# %%
#--MANUALLY CHANGEABLE--

#amount of variance I want to explain
explained_variance = .99

#number of components to show on the plot
components = 50

# -- * --

#see how much variance is explained if I reduce it down
pca = PCA(n_components = components).fit(X)

#A function that will tell you how many components to retain if you want to explain a certain portion of variance (0-1)?
def retain(portion):
    for i,v in enumerate(pca.explained_variance_ratio_.cumsum()):
        if v > portion:
            return i + 1
            break

figure(figsize = (20, 7))
plt.bar(arange(components) + .5, pca.explained_variance_ratio_.cumsum())
plt.ylim((0, 1))

#Run the retain function here; 

components = retain(explained_variance)
pylab.title("keep " + str(components) + ' components to explain ' + str(explained_variance) + ' of the variance', fontsize=30)


#other axis labels
plt.xlabel('No. of principal components', fontsize=20)
plt.ylabel('Cumulative variance explained', fontsize=20)
plt.grid(axis = 'y', ls = '-', lw = 1, color = 'black')

# %% [markdown]
# I want to keep almost all of information that I have on the hoods.  I just want to reduce redundancy so that redundant features do not get overcounted (redundancy is a byproduct of the way I got the information (e.g., crime having 30 features)) .  So I am going to keep the number of components that explain 99% of the origianl dataset.  This reduces the number of variables from 98 to 42.

# %%
print 'You need to keep ' + str(components) + ' components' + ' to explain ' + str(explained_variance) + ' of your variance.'
pca = PCA(n_components = components).fit(X)
hoods_reduced = pca.fit_transform(X)
# Out:
# You need to keep 42 components to explain 0.99 of your variance.

# %%
pd.DataFrame(hoods_reduced).to_csv('/Users/anson/Documents/Office/zipfian/repos/Personal_project/hoods_data/final_to_analyze/hoods_reducedfeatures.csv')

# %% [markdown]
# ## Compute similarity matrix

# %% [raw]
# Now make a similarity matrix of the hoods using the 18 PCA components.

# %%
#set the type of similarity metric here (e.g., euclidean, correlation, cosine)
similarity_metric = 'correlation'
#create similarity matrix
hoods_similarity_np = pairwise.pairwise_distances(hoods_reduced, metric=similarity_metric, n_jobs=4)

#make a csv copy
hoods_similarity = pd.DataFrame(hoods_similarity_np)
hoods_similarity.to_csv('/Users/anson/Documents/Office/zipfian/repos/Personal_project/hoods_data/final_to_analyze/hoods_similarity_matrix.csv')

# %%
hoods_similarity.iloc[2:4]
# Out:
# /Users/anson/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /Users/anson/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /Users/anson/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 2 to 3
# Columns: 111 entries, 0 to 110
# dtypes: float64(111)

# %% [markdown]
# ## EXAMINE THE MATRIX!

# %% [markdown]
# I am going to examine the matrix in a few ways, in part to see if similarity matrix does a good job assessing similarities between hoods.  I also want to see the matrix produces any interesting insights about hoods in SF.

# %% [markdown]
# First make lookup tables.

# %%
hood_rev_lookup = dict(hood_names)
#hood_rev_lookup

#create dictionary that will allow me to find the row number of hood/district
hood_lookup={}
for k,v in hood_rev_lookup.items():
    hood_lookup[v]=k

# %% [markdown]
# Write a function that is going to return you a list of similar hoods.  1st argument should be target hood, 2cd argument should be number of similar hoods to list, move from most similar to less similar

# %%
#find similar hoods 
def similar_hoods(hood, numb_hoods):
    #select row of hood you are interested in, returning list of similarity scores / how similar each hood is to target hood
    hoodlist=hoods_similarity.ix[hood_lookup[hood],:]
    
    #now use hood_rev_lookup to get names of most similar hoods
    similar_hoods=[]
    for k, v in hood_rev_lookup.items():
        for i in range(1,numb_hoods+1):
            simhood=pd.Series(np.sort(hoodlist)).iloc[i:i+1].index.values
            if k == simhood:
                similar_hoods.append(str(i)+'. '+v)
    return 'Sim to ' + str(hood) + ': ' + str(sorted(similar_hoods))

# %% [markdown]
# test it out on hoods that I know to see if it seem reasonable (it does!)

# %%
#These are hoods I know about and can assess whether the top 5 similar hoods are reasonable
print similar_hoods('Haight Ashbury', 5)
print similar_hoods('Outer Sunset', 5)
print similar_hoods('Outer Richmond', 5)
print similar_hoods('Russian Hill', 5)
print similar_hoods('Noe Valley', 5)
print similar_hoods('Castro', 5)
print similar_hoods('Mission', 5)
print similar_hoods('Potrero Hill', 5)
print similar_hoods('Tenderloin', 5)
print similar_hoods('Dogpatch', 5)
print similar_hoods('Excelsior', 5)
print similar_hoods('Visitacion Valley', 5)
print similar_hoods('Hunters Point', 5)
print similar_hoods('Bayview', 5)
print similar_hoods('Marina', 5)
#they seem highly reasonable!
# Out:
# Sim to Haight Ashbury: ['1. Cole Valley', '2. Panhandle', '3. Lower Haight', '4. Hayes Valley', '5. Duboce Triangle']
# Sim to Outer Sunset: ['1. Lakeshore', '2. Parkside', '3. Outer Richmond', '4. Hunters Point', '5. Crocker Amazon']
# Sim to Outer Richmond: ['1. Outer Sunset', '2. Parkside', '3. Crocker Amazon', '4. Lakeshore', '5. Merced Heights']
# Sim to Russian Hill: ['1. Nob Hill', '2. Telegraph Hill', '3. Castro', '4. Noe Valley', '5. Union Street']
# Sim to Noe Valley: ['1. Ashbury Heights', '2. Cow Hollow', '3. Holly Park', '4. Russian Hill', '5. Peralta Heights']
# Sim to Castro: ['1. Hayes Valley', '2. Civic Center', '3. Lower Pacific Heights', '4. Duboce Triangle', '5. Polk Gulch']
# Sim to Mission: ['1. Mission Dolores', '2. South of Market', '3. Lower Haight', '4. Lower Nob Hill', '5. Tenderloin']
# Sim to Potrero Hill: ['1. Hunters Point', '2. Silver Terrace', '3. Mission Bay', '4. Sunnydale', '5. Bayview']
# Sim to Tenderloin: ['1. Lower Nob Hill', '2. North Beach', '3. Mission', '4. South of Market', '5. Civic Center']
# Sim to Dogpatch: ['1. Showplace Square', '2. Rincon Hill', '3. Apparel City', '4. Produce Market', '5. Financial District']
# Sim to Excelsior: ['1. Portola', '2. Outer Mission', '3. Bayview', '4. Silver Terrace', '5. Mission Terrace']
# Sim to Visitacion Valley: ['1. Inner Sunset', '2. Bayview', '3. Central Waterfront', '4. Hunters Point', '5. Candlestick Point SRA']
# Sim to Hunters Point: ['1. Candlestick Point SRA', '2. India Basin', '3. Treasure Island', '4. Midtown Terrace', '5. Sherwood Forest']
# Sim to Bayview: ['1. Central Waterfront', '2. Silver Terrace', '3. Portola', '4. Visitacion Valley', '5. Excelsior']
# Sim to Marina: ['1. Mission Bay', '2. Parnassus Heights', '3. Fishermans Wharf', '4. Parkmerced', '5. Lakeshore']

# %%
#RUN THIS TO FIND TO find top three similar hoods for all neighborhoods in SF
for i in hood_names:
    print similar_hoods(i, 4)
# Out:
# Sim to Alamo Square: ['1. Mission Dolores', '2. Panhandle', '3. Duboce Triangle', '4. Lower Haight']
# Sim to Anza Vista: ['1. Lone Mountain', '2. Fishermans Wharf', '3. Parnassus Heights', '4. Mission Bay']
# Sim to Apparel City: ['1. Mission Bay', '2. India Basin', '3. Hunters Point', '4. Diamond Heights']
# Sim to Ashbury Heights: ['1. Noe Valley', '2. Corona Heights', '3. Holly Park', '4. Russian Hill']
# Sim to Balboa Terrace: ['1. Glen Park', '2. Sunnyside', '3. St. Francis Wood', '4. Merced Manor']
# Sim to Bayview: ['1. Central Waterfront', '2. Silver Terrace', '3. Portola', '4. Visitacion Valley']
# Sim to Bernal Heights: ['1. Peralta Heights', '2. Holly Park', '3. Corona Heights', '4. Buena Vista']
# Sim to Bret Harte: ['1. Produce Market', '2. Ingleside', '3. Sunnydale', '4. Mission Terrace']
# Sim to Buena Vista: ['1. Panhandle', '2. Peralta Heights', '3. Bernal Heights', '4. Corona Heights']
# Sim to Candlestick Point SRA: ['1. Treasure Island', '2. India Basin', '3. Hunters Point', '4. Midtown Terrace']
# Sim to Castro: ['1. Hayes Valley', '2. Civic Center', '3. Lower Pacific Heights', '4. Duboce Triangle']
# Sim to Cathedral Hill: ['1. Civic Center', '2. Lower Pacific Heights', '3. Hayes Valley', '4. Lower Nob Hill']
# Sim to Cayuga: ['1. West Portal', '2. Little Hollywood', '3. Merced Manor', '4. Cole Valley']
# Sim to Central Waterfront: ['1. Bayview', '2. Visitacion Valley', '3. Portola', '4. Ingleside Terraces']
# Sim to Chinatown: ['1. Downtown / Union Square', '2. Financial District', '3. North Beach', '4. Lower Nob Hill']
# Sim to Civic Center: ['1. Cathedral Hill', '2. Mission Dolores', '3. South of Market', '4. Castro']
# Sim to Clarendon Heights: ['1. Midtown Terrace', '2. Laguna Honda', '3. Forest Knolls', '4. Sutro Heights']
# Sim to Cole Valley: ['1. Haight Ashbury', '2. Duboce Triangle', '3. Panhandle', '4. Mint Hill']
# Sim to Corona Heights: ['1. Ashbury Heights', '2. Fairmount', '3. Peralta Heights', '4. Bernal Heights']
# Sim to Cow Hollow: ['1. Noe Valley', '2. Lower Pacific Heights', '3. Presidio Heights', '4. Ashbury Heights']
# Sim to Crocker Amazon: ['1. Golden Gate Heights', '2. Merced Heights', '3. Oceanview', '4. Midtown Terrace']
# Sim to Diamond Heights: ['1. Midtown Terrace', '2. Laguna Honda', '3. Candlestick Point SRA', '4. Treasure Island']
# Sim to Dogpatch: ['1. Showplace Square', '2. Rincon Hill', '3. Apparel City', '4. Produce Market']
# Sim to Dolores Heights: ['1. Telegraph Hill', '2. Noe Valley', '3. Lower Haight', '4. Russian Hill']
# Sim to Downtown / Union Square: ['1. South of Market', '2. Financial District', '3. North Beach', '4. Lower Nob Hill']
# Sim to Duboce Triangle: ['1. Mission Dolores', '2. Cole Valley', '3. Lower Haight', '4. Mint Hill']
# Sim to Eureka Valley: ['1. Fairmount', '2. Western Addition', '3. University Mound', '4. Golden Gate Heights']
# Sim to Excelsior: ['1. Portola', '2. Outer Mission', '3. Bayview', '4. Silver Terrace']
# Sim to Fairmount: ['1. Eureka Valley', '2. Corona Heights', '3. Peralta Heights', '4. Golden Gate Heights']
# Sim to Financial District: ['1. Downtown / Union Square', '2. Chinatown', '3. North Beach', '4. South of Market']
# Sim to Fishermans Wharf: ['1. Marina', '2. Mission Bay', '3. Apparel City', '4. Parnassus Heights']
# Sim to Forest Hill: ['1. Monterey Heights', '2. Sherwood Forest', '3. Laguna Honda', '4. Westwood Highlands']
# Sim to Forest Knolls: ['1. Midtown Terrace', '2. Sherwood Forest', '3. Clarendon Heights', '4. Monterey Heights']
# Sim to Glen Park: ['1. Sunnyside', '2. St. Marys Park', '3. Clarendon Heights', '4. Mission Terrace']
# Sim to Golden Gate Heights: ['1. Crocker Amazon', '2. Ingleside', '3. Oceanview', '4. University Mound']
# Sim to Haight Ashbury: ['1. Cole Valley', '2. Panhandle', '3. Lower Haight', '4. Hayes Valley']
# Sim to Hayes Valley: ['1. Lower Pacific Heights', '2. Lower Haight', '3. Castro', '4. Mission Dolores']
# Sim to Holly Park: ['1. Bernal Heights', '2. Ashbury Heights', '3. St. Marys Park', '4. Corona Heights']
# Sim to Hunters Point: ['1. Candlestick Point SRA', '2. India Basin', '3. Treasure Island', '4. Midtown Terrace']
# Sim to India Basin: ['1. Candlestick Point SRA', '2. Treasure Island', '3. Hunters Point', '4. Diamond Heights']
# Sim to Ingleside: ['1. Golden Gate Heights', '2. Oceanview', '3. Crocker Amazon', '4. Sunnyside']
# Sim to Ingleside Terraces: ['1. Portola', '2. Central Waterfront', '3. Excelsior', '4. Miraloma Park']
# Sim to Inner Richmond: ['1. Mission Dolores', '2. Bernal Heights', '3. Excelsior', '4. Presidio Terrace']
# Sim to Inner Sunset: ['1. Visitacion Valley', '2. Bayview', '3. Central Waterfront', '4. Mission']
# Sim to Japantown: ['1. Downtown / Union Square', '2. North Beach', '3. Lower Haight', '4. South of Market']
# Sim to Laguna Honda: ['1. Monterey Heights', '2. Clarendon Heights', '3. Sherwood Forest', '4. Midtown Terrace']
# Sim to Lake Street: ['1. Parnassus Heights', '2. Sutro Heights', '3. Seacliff', '4. Lone Mountain']
# Sim to Lakeshore: ['1. Outer Sunset', '2. Parkside', '3. Hunters Point', '4. Treasure Island']
# Sim to Laurel Heights / Jordan Park: ['1. Seacliff', '2. Peralta Heights', '3. Bernal Heights', '4. Lake Street']
# Sim to Little Hollywood: ['1. Midtown Terrace', '2. Laguna Honda', '3. Sutro Heights', '4. Forest Knolls']
# Sim to Lone Mountain: ['1. Presidio Terrace', '2. Parnassus Heights', '3. Lake Street', '4. Presidio Heights']
# Sim to Lower Haight: ['1. Mission', '2. Duboce Triangle', '3. Hayes Valley', '4. Mission Dolores']
# Sim to Lower Nob Hill: ['1. Tenderloin', '2. North Beach', '3. Polk Gulch', '4. Civic Center']
# Sim to Lower Pacific Heights: ['1. Hayes Valley', '2. Cathedral Hill', '3. Castro', '4. Civic Center']
# Sim to Marina: ['1. Mission Bay', '2. Parnassus Heights', '3. Fishermans Wharf', '4. Parkmerced']
# Sim to Merced Heights: ['1. Crocker Amazon', '2. Diamond Heights', '3. Sutro Heights', '4. Little Hollywood']
# Sim to Merced Manor: ['1. Westwood Park', '2. Stonestown', '3. Parnassus Heights', '4. Monterey Heights']
# Sim to Midtown Terrace: ['1. Forest Knolls', '2. Sherwood Forest', '3. Clarendon Heights', '4. Laguna Honda']
# Sim to Mint Hill: ['1. Duboce Triangle', '2. Cole Valley', '3. Mission Dolores', '4. Polk Gulch']
# Sim to Miraloma Park: ['1. Golden Gate Heights', '2. Westwood Highlands', '3. University Mound', '4. Sherwood Forest']
# Sim to Mission: ['1. Mission Dolores', '2. South of Market', '3. Lower Haight', '4. Lower Nob Hill']
# Sim to Mission Bay: ['1. Parkmerced', '2. Apparel City', '3. Parnassus Heights', '4. Hunters Point']
# Sim to Mission Dolores: ['1. Mission', '2. Alamo Square', '3. Duboce Triangle', '4. Civic Center']
# Sim to Mission Terrace: ['1. St. Marys Park', '2. Silver Terrace', '3. Glen Park', '4. Outer Mission']
# Sim to Monterey Heights: ['1. Sherwood Forest', '2. Laguna Honda', '3. Midtown Terrace', '4. Forest Knolls']
# Sim to Mt. Davidson Manor: ['1. Ingleside', '2. Monterey Heights', '3. Forest Hill', '4. West Portal']
# Sim to Nob Hill: ['1. Russian Hill', '2. Union Street', '3. Lower Nob Hill', '4. Polk Gulch']
# Sim to Noe Valley: ['1. Ashbury Heights', '2. Cow Hollow', '3. Holly Park', '4. Russian Hill']
# Sim to North Beach: ['1. Polk Gulch', '2. Lower Nob Hill', '3. Union Street', '4. Downtown / Union Square']
# Sim to Northern Waterfront: ['1. Fishermans Wharf', '2. Financial District', '3. Rincon Hill', '4. Mission Bay']
# Sim to Oceanview: ['1. Golden Gate Heights', '2. Crocker Amazon', '3. Ingleside', '4. Sunnyside']
# Sim to Outer Mission: ['1. Silver Terrace', '2. Merced Heights', '3. Crocker Amazon', '4. Excelsior']
# Sim to Outer Richmond: ['1. Outer Sunset', '2. Parkside', '3. Crocker Amazon', '4. Lakeshore']
# Sim to Outer Sunset: ['1. Lakeshore', '2. Parkside', '3. Outer Richmond', '4. Hunters Point']
# Sim to Pacific Heights: ['1. South of Market', '2. Inner Sunset', '3. Nob Hill', '4. Cow Hollow']
# Sim to Panhandle: ['1. Haight Ashbury', '2. Alamo Square', '3. Presidio Terrace', '4. Buena Vista']
# Sim to Parkmerced: ['1. Stonestown', '2. Parnassus Heights', '3. Sutro Heights', '4. Forest Knolls']
# Sim to Parkside: ['1. Outer Sunset', '2. Lakeshore', '3. Crocker Amazon', '4. Merced Heights']
# Sim to Parnassus Heights: ['1. Parkmerced', '2. Laguna Honda', '3. Stonestown', '4. Merced Manor']
# Sim to Peralta Heights: ['1. Bernal Heights', '2. Corona Heights', '3. Buena Vista', '4. Fairmount']
# Sim to Polk Gulch: ['1. North Beach', '2. Lower Nob Hill', '3. Castro', '4. Union Street']
# Sim to Portola: ['1. Excelsior', '2. Bayview', '3. Hunters Point', '4. Central Waterfront']
# Sim to Potrero Hill: ['1. Hunters Point', '2. Silver Terrace', '3. Mission Bay', '4. Sunnydale']
# Sim to Presidio Heights: ['1. Presidio Terrace', '2. Lone Mountain', '3. Parnassus Heights', '4. Lake Street']
# Sim to Presidio Terrace: ['1. Lone Mountain', '2. Presidio Heights', '3. Panhandle', '4. Seacliff']
# Sim to Produce Market: ['1. Bret Harte', '2. Outer Mission', '3. Parkmerced', '4. Mission Terrace']
# Sim to Rincon Hill: ['1. Dogpatch', '2. South Beach', '3. Financial District', '4. Northern Waterfront']
# Sim to Russian Hill: ['1. Nob Hill', '2. Telegraph Hill', '3. Castro', '4. Noe Valley']
# Sim to Seacliff: ['1. Sutro Heights', '2. Forest Knolls', '3. Clarendon Heights', '4. Westwood Highlands']
# Sim to Sherwood Forest: ['1. Midtown Terrace', '2. Forest Knolls', '3. Monterey Heights', '4. Laguna Honda']
# Sim to Showplace Square: ['1. Dogpatch', '2. Apparel City', '3. Produce Market', '4. Union Street']
# Sim to Silver Terrace: ['1. Outer Mission', '2. Bayview', '3. Mission Terrace', '4. Potrero Hill']
# Sim to South Beach: ['1. Rincon Hill', '2. Cow Hollow', '3. Castro', '4. Telegraph Hill']
# Sim to South of Market: ['1. Mission', '2. Downtown / Union Square', '3. Civic Center', '4. Lower Nob Hill']
# Sim to St. Francis Wood: ['1. Monterey Heights', '2. Laguna Honda', '3. Merced Manor', '4. Clarendon Heights']
# Sim to St. Marys Park: ['1. Mission Terrace', '2. Glen Park', '3. Bret Harte', '4. Apparel City']
# Sim to Stonestown: ['1. Parkmerced', '2. Parnassus Heights', '3. Merced Manor', '4. Clarendon Heights']
# Sim to Sunnydale: ['1. Bret Harte', '2. Potrero Hill', '3. University Mound', '4. Miraloma Park']
# Sim to Sunnyside: ['1. Sherwood Forest', '2. Westwood Park', '3. Midtown Terrace', '4. Forest Hill']
# Sim to Sutro Heights: ['1. Forest Knolls', '2. Clarendon Heights', '3. Midtown Terrace', '4. Laguna Honda']
# Sim to Telegraph Hill: ['1. Russian Hill', '2. Nob Hill', '3. Dolores Heights', '4. North Beach']
# Sim to Tenderloin: ['1. Lower Nob Hill', '2. North Beach', '3. Mission', '4. South of Market']
# Sim to Treasure Island: ['1. Candlestick Point SRA', '2. India Basin', '3. Hunters Point', '4. Midtown Terrace']
# Sim to Union Street: ['1. North Beach', '2. Nob Hill', '3. Polk Gulch', '4. Downtown / Union Square']
# Sim to University Mound: ['1. Golden Gate Heights', '2. Miraloma Park', '3. India Basin', '4. Crocker Amazon']
# Sim to Upper Market: ['1. Sutro Heights', '2. Clarendon Heights', '3. Forest Knolls', '4. Sherwood Forest']
# Sim to Visitacion Valley: ['1. Inner Sunset', '2. Bayview', '3. Central Waterfront', '4. Hunters Point']
# Sim to West Portal: ['1. Cayuga', '2. Merced Manor', '3. Sunnyside', '4. Merced Heights']
# Sim to Western Addition: ['1. Eureka Valley', '2. Fairmount', '3. Mission Dolores', '4. Mission']
# Sim to Westwood Highlands: ['1. Sherwood Forest', '2. Monterey Heights', '3. Midtown Terrace', '4. Forest Knolls']
# Sim to Westwood Park: ['1. Merced Manor', '2. Sherwood Forest', '3. Sunnyside', '4. Monterey Heights']

# %% [markdown]
# Given what I know (my domain knowledge) about SF, the similarity matrix appears to do a fantantastic job capturing hood similarity.   The results are similar to what I would give.
#
# Interestingly, even though geographic information (e.g., closeness) was not a feature, often areas close to each other are labeled as being similar.

# %% [markdown]
# # Hierarchical cluster of the data

# %% [markdown]
# I want to visualize which neighborhoods are similar to each other.

# %%
# perform clustering and plot the dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram
titles = np.array(hood_names)

#make the dendogram using the hoods_similarity matrix
figure(figsize(10,30))
R = dendrogram(linkage(hoods_similarity, method='complete'), labels = titles, leaf_font_size=10, orientation='left' )
    #use labels above to pass a vector that contains the values you want to have as the labels of the datapoints
xlabel('Hoods', fontsize=4)
ylabel('Height')
suptitle('SF Hoods Cluster Dendrogram', fontweight='bold', fontsize=14);

# %% [markdown]
# Very cool!  The difference between red and green neighborhoods is noticeable.  For the most part, green hoods are busy and/or rich, while red hoods are sleepier and/or poorer.

# %% [markdown]
# # Multidimensional scaling

# %% [markdown]
# Another visual representation of neighborhood similarities.  Again, my features seem to capture similaries between SF hoods rather well.  There is a sub cluster that seem to represent parts of town that are very dead (e.g. TI, India basin, etc.)

# %%
from sklearn.manifold import MDS

#performce MDS
mds=MDS(dissimilarity='precomputed')
hood_mds=mds.fit_transform(hoods_similarity)
hood_names = np.array(hood_names)

#Plot the MDS
figsize(25, 15)
plt.scatter(hood_mds[:, 0], hood_mds[:, 1],  marker='+', alpha=0)
plt.title('Similarity between Hoods in San Francisco')

for i in hoods_similarity:
    plt.annotate(hood_names[i], (hood_mds[i, 0], hood_mds[i, 1]),
                 color = 'red',
                 alpha = 0.7, 
                 fontsize = 12,
                 horizontalalignment = 'center', 
                 verticalalignment = 'center',
                 family = 'sans-serif')
# Turn off axes labels.
plt.setp(plt.gca().get_yaxis(), visible = False)
plt.setp(plt.gca().get_xaxis(), visible = False)
plt.show()

# %% [markdown]
# # WRITING/SAVE THE OUTPUT

# %% [markdown]
# FIRST, I am going to add the hood names back to similarity matrix and then write it to a csv file

# %%
#save the hoods_similarity matrix - the one with out names
hoods_similarity.to_csv('/Users/anson/Documents/Office/zipfian/repos/Personal_project/hoods_data/output/hoods_similarity.csv')

hoods_similarity_renamed = hoods_similarity.rename(columns=hood_rev_lookup)

hoods_similarity_renamed['hoods'] = hood_rev_lookup.values()
hoods_similarity_renamed = hoods_similarity_renamed.set_index(['hoods'])
hoods_similarity_renamed.to_csv('/Users/anson/Documents/Office/zipfian/repos/Personal_project/hoods_data/output/hoods_similarity_renamed.csv')

#quick check.  Hood similarity matrix.  Lower numbers means less similary!
hoods_similarity_renamed.ix[:5, :20]
# Out:
# /Users/anson/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /Users/anson/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /Users/anson/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
#                  Alamo Square  Anza Vista  Apparel City  Ashbury Heights  \
# hoods
# Alamo Square         0.000000    1.058993      1.358861         0.671715
# Anza Vista           1.058993    0.000000      0.789644         1.191218
# Apparel City         1.358861    0.789644      0.000000         1.232378
# Ashbury Heights      0.671715    1.191218      1.232378         0.000000
# Balboa Terrace       0.857211    0.977062      0.976164         0.886777
#
#                  Balboa Terrace   Bayview  Bernal Heights  Bret Harte  \
# hoods
# Alamo Square           0.857211  1.342834        0.970897    1.284477
# Anza Vista             0.977062  1.084100        1.193919    0.958549
# Apparel City           0.976164  0.805632        1.122736    0.628322
# Ashbury Heights        0.886777  1.193955        0.701152    1.155613
# Balboa Terrace         0.000000  0.987826        0.994229    0.971534
#
#                  Buena Vista  Candlestick Point SRA    Castro  Cathedral Hill  \
# hoods
# Alamo Square        0.689201               1.457770  0.735683        0.649512
# Anza Vista          0.764119               0.909095  1.247969        1.211311
# Apparel City        1.004000               0.434133  1.492444        1.338650
# Ashbury Heights     0.728497               1.124771  0.719995        1.136326
# Balboa Terrace      0.815349               0.810934  1.331463        1.227468
#
#                    Cayuga  Central Waterfront  Chinatown  Civic Center  \
# hoods
# Alamo Square     1.147455            1.294284   0.857983      0.663838
# Anza Vista       0.979200            0.901004   1.198501      1.045250
# Apparel City     0.945568            0.654349   1.273952      1.369110
# Ashbury Heights  0.926467            1.205890   1.180025      1.178563
# Balboa Terrace   0.906766            0.922282   1.306963      1.254741
#
#                  Clarendon Heights  Cole Valley  Corona Heights  Cow Hollow
# hoods
# Alamo Square              1.410539     0.753694        0.814869    1.094917
# Anza Vista                0.773270     0.796976        0.975187    0.837453
# Apparel City              0.465355     1.258113        1.035470    0.854504
# Ashbury Heights           1.031513     0.803893        0.427971    0.620971
# Balboa Terrace            0.599286     1.076307        0.697850    1.220392

# %% [markdown]
# SECOND, I am going to make a file that can be easily uploaded into CARTODB, so that I can make a quick interactive visualization

# %%
hoods_sim_names=pd.read_csv(open('/Users/anson/Documents/Office/zipfian/repos/Personal_project/hoods_data/output/hoods_similarity_renamed.csv'))
hoods_carto=pd.read_csv(open('/Users/anson/Documents/Office/zipfian/repos/Personal_project/to_visualize/hoods_cartodb.csv'))
carto_similarity = hoods_carto.merge(hoods_sim_names, on = 'hoods')
carto_similarity.ix[:2, :15]

carto_similarity.to_csv('/Users/anson/Documents/Office/zipfian/repos/Personal_project/to_visualize/carto_similarity.csv')
